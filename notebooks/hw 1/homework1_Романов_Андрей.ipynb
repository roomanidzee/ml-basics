# %% [markdown]
# ## Домашнее задание 1
# ### Основы Python и пакет NumPy
# ---

# %%
import numpy as np
import random
import scipy.stats as sps

# %% [markdown]
# ## Задача 0
# В этом разделе нам хотелось бы увидеть базовые навыки в языке програмирования Python

# %% [markdown]
# ### __0.1__
# Дано натуральное число. Требуется определить, является ли год с данным номером високосным. Если год является високосным, то выведите YES, иначе выведите NO. Напомним, что в соответствии с григорианским календарем, год является високосным, если его номер кратен 4, но не кратен 100, а также если он кратен 400.

# %%
def is_leap_year(year):

    if (year % 4 == 0) and (year % 100 != 0) or (year % 400 == 0):
        return "YES"
    else:
        return "NO"

# %%
print(is_leap_year(1000))
print(is_leap_year(400))
print(is_leap_year(1001))
print(is_leap_year(1004))
# Out:
# NO
# YES
# NO
# YES

# %% [markdown]
# ### __0.2__
# Дано натуральное число. Найдите число десятков в его десятичной записи.

# %%
def num_decs(number):
    return number // 10 % 10

# %%
print(num_decs(15634780))
print(num_decs(101))
# Out:
# 8
# 0

# %% [markdown]
# ### __0.3__
# По данному натуральном n вычислите сумму 1!+2!+3!+...+n!. В решении этой задачи можно использовать только один цикл. Пользоваться математической библиотекой math в этой задаче запрещено.

# %%
def factorial_sum(n):
    temp_fact = 1
    temp_sum = 0
    for i in range(1, n + 1):
        temp_fact *= i
        temp_sum += temp_fact

    return temp_sum

# %%
print(factorial_sum(4))
print(factorial_sum(10))
# Out:
# 33
# 4037913

# %% [markdown]
# ### __0.4__
#  Определить, является ли введённая строка палиндромом (то есть одинаково читается с обеих сторон).

# %%
def is_palindrome(s):
    normalized_str = s.replace(' ', '').lower()

    return normalized_str == normalized_str[::-1]

# %%
print(is_palindrome("бащаб"))
print(is_palindrome("А роза упала на лапу Азора"))
# Out:
# True
# True

# %% [markdown]
# # Задача 1
# В первой задаче вам предлагается перемножить две матрицы двумя способами -- без использования пакета ***numpy*** и с ним. Использовать матричное произведение.

# %%
# Для генерации матриц используем фукнцию random -- она используется для генерации случайных объектов 
# функция sample создает случайную выборку. В качестве аргумента ей передается кортеж (i,j), здесь i -- число строк,
# j -- число столбцов.
a = np.random.sample((100,1000))
b = np.random.sample((1000,100))
# выведите размерность (ранг) каждой матрицы с помощью функции ndim.
# Используйте функцию shape, что она вывела?
# ========
# тут можно писать код 
# ========
print(f"matrix a: ndim {a.ndim}, shape {a.shape}")
print(f"matrix b: ndim {b.ndim}, shape {b.shape}")
# Out:
# matrix a: ndim 2, shape (100, 1000)
# matrix b: ndim 2, shape (1000, 100)

# %%
def mult(a, b):
    # здесь напишите перемножение матриц без 
    # использования NumPy и выведите результат 
    zip_b = list(zip(*b))

    result =  [
        [
            sum(ele_a*ele_b for ele_a, ele_b in zip(row_a, col_b)) 
            for col_b in zip_b
        ] for row_a in a
    ]

    print(result)

# %%
def np_mult(a, b):
    # здесь напишите перемножение матриц с
    # использованием NumPy и выведите результат
    result = np.matrix(a) * np.matrix(b)
    print(result)

# %%
# Превратим матрицы в листы, чтобы протестировать функцию без np
a_list = [[x for x in row] for row in a]
b_list = [[x for x in row] for row in b]

# %%
# %%time
# засечем время работы функции без NumPy
mult(a_list, b_list)
# Out:
# [[249.33142286426124, 245.29904121324097, 244.59014824361307, 248.5739558239618, 247.28148580327044, 257.52834072386935, 252.71247756248923, 240.3757065519363, 253.75525148952363, 239.6012672108818, 241.77775374126983, 252.51964681281635, 250.6732461887637, 244.26056256036705, 246.44311086790333, 245.18527709988717, 237.64249161689088, 249.42381324879037, 244.45182984867418, 254.56726701422613, 237.16089730917463, 249.93574630607648, 248.25879829156662, 242.7212898719093, 239.10331055247116, 249.02738797168317, 249.9265023033777, 254.85856396377477, 242.9052305091271, 249.5056923505835, 248.69468538883828, 247.01391211266653, 249.04108516141136, 246.0426643213209, 244.66621601425277, 231.91006084116523, 247.50396882838675, 256.8083987245674, 244.56143628260187, 248.42876819283768, 251.19251596014783, 247.56338231058444, 244.7181029835172, 252.38232997443464, 248.50884873390476, 252.64844912287532, 254.00361666683452, 240.22641560345426, 240.82562747113255, 241.32784140321374, 254.675
# ...

# %%
# %%time
# засечем время работы функции с NumPy
np_mult(a, b)
# Out:
# [[249.33142286 245.29904121 244.59014824 ... 241.45474057 253.91997331
#   244.71157235]
#  [250.20877901 249.50598785 244.1914701  ... 253.75068307 253.73199751
#   240.70230034]
#  [240.13772098 245.55556176 239.76551762 ... 245.15531898 247.80573125
#   237.28434962]
#  ...
#  [240.86397997 241.25687646 238.3860188  ... 253.55766853 248.98670842
#   247.30457161]
#  [247.92848753 255.26493138 245.8714231  ... 258.09031106 254.2110511
#   243.38087272]
#  [244.70521481 239.42599664 245.394806   ... 249.16574067 250.67404293
#   238.53254015]]
# CPU times: user 4.02 ms, sys: 5.02 ms, total: 9.04 ms
# Wall time: 14.9 ms

# %% [markdown]
# ## Задача 2
# Напишите функцию, которая по данной последовательности $\{A_i\}_{i=1}^n$ строит последовательность $S_n$, где $S_k = \frac{A_1 + ... + A_k}{k}$.
# Аналогично -- с помощью библиотеки **NumPy** и без нее. Сравните скорость, объясните результат.

# %%
# функция, решающая задачу с помощью NumPy
def sec_av(A):
    # Ваш код здесь
    new_arr = np.zeros(A.shape)

    limit = A.shape[0]

    for i in range(limit):
        new_arr[i] = np.sum(A[0:i + 1]) / (i + 1)

    return new_arr

# %%
# функция без NumPy
def stupid_sec_av(A):
    # Ваш код здесь
    return [
        sum(A[0:i + 1]) / (i + 1)
        for i in range(len(A))
    ]

# %%
# зададим некоторую последовательность и проверим ее на ваших функциях. 
# Первая функция должна работать ~ в 50 раз быстрее
A = sps.uniform.rvs(size=10 **3) 
A_list = list(A)

# %%
# %time S1 = sec_av(A)
# Out:
# CPU times: user 9.75 ms, sys: 0 ns, total: 9.75 ms
# Wall time: 12.6 ms

# %%
# %time S2 = stupid_sec_av(A_list)
# Out:
# CPU times: user 77.5 ms, sys: 1.67 ms, total: 79.1 ms
# Wall time: 80.4 ms

# %%
#проверим корректность:
np.abs(S1 - S2).sum()
# Out:
# 1.308397834520747e-13

# %% [markdown]
# ## Задача 3
#
# Пусть задан некоторый массив $X$. Надо построить новый массив, где все элементы с нечетными индексами требуется заменить на число $a$ (если оно не указано, то на 1). Все элементы с четными индексами исходного массива нужно возвести в куб и записать в обратном порядке относительно позиций этих элементов. Массив $X$ при этом должен остаться без изменений. В конце требуется слить (конкатенировать) массив X с преобразованным X и вывести в обратном порядке.

# %%
# функция, решающая задачу с помощью NumPy
def transformation(X, a=1):
    new_arr = np.flip(X)

    new_arr[new_arr % 2 == 1] = a
    new_arr[new_arr % 2 == 0] ** 3

    return np.flip(np.concatenate((X, new_arr)))

# %%
# функция, решающая задачу  без NumPy
def stupid_transformation(X, a=1):
    Y = list(reversed(X))

    for index, elem in enumerate(X):
        if index % 2 != 0:
            Y[index] = elem

    for index, elem in enumerate(Y):
        if index % 2 != 0:
            Y[index] = a
        
        if index % 2 == 0:
            Y[index] = elem ** 3

    final_arr = X + Y
    return list(reversed(final_arr))

# %%
X = sps.uniform.rvs(size=10 ** 3)
X_list = list(X)
# здесь код эффективнее примерно в 20 раз. 
# если Вы вдруг соберетесь печатать массив без np -- лучше сначала посмотрите на его размер
# %time S1 = transformation(X)
# %time S2 = stupid_transformation(X_list)
# проверим корректность:
print(np.abs(S1 - S2).sum())
# Out:
# CPU times: user 176 µs, sys: 0 ns, total: 176 µs
# Wall time: 183 µs
# CPU times: user 848 µs, sys: 0 ns, total: 848 µs
# Wall time: 969 µs
# 372.4757418029173

# %% [markdown]
# Почему методы ***numpy*** оказываются эффективнее?

# %%
# Ваш ответ
# Numpy эффективней, так как он работает в оперативной памяти с непрерывным участком одно типных данных. Также, реализация массивов - это ссылочная структура C++, когда память выделяется блоками

# %% [markdown]
# ## Дополнительные задачи

# %% [markdown]
# Дополнительные задачи подразумевают, что Вы самостоятельно разберётесь в некоторых функциях ***numpy***, чтобы их сделать, но в то же время не являются обязательными.

# %% [markdown]
# ## Задача 4*

# %% [markdown]
# Дана функция двух переменных: $f(x, y) = sin(x)cos(y)$ (это просто такой красивый 3D-график), а также дана функция для отрисовки $f(x, y)$ (`draw_f()`), которая принимает на вход двумерную сетку, на которой будет вычисляться функция.
#
# Вам нужно разобраться в том, как строить такие сетки (подсказка - это одна конкретная функция ***numpy***), и подать такую сетку на вход функции отрисовки.

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

def f(x, y):
    '''Функция двух переменных'''
    return np.sin(x) * np.cos(y)

def draw_f(grid_x, grid_y):
    '''Функция отрисовки функции f(x, y)'''
    fig = plt.figure(figsize=(10, 8))
    ax = Axes3D(fig)
    ax.plot_surface(grid_x, grid_y, f(grid_x, grid_y), cmap='inferno')
    plt.show()

# %%
nx, ny = (3, 2)

x = np.linspace(0, 5, nx)
y = np.linspace(0, 5, ny)

grid_x, grid_y = np.meshgrid(x, y, sparse=True)

draw_f(grid_x, grid_y)

# %% [markdown]
# ## Задача 5*

# %% [markdown]
# Вам дана картинка. При загрузке её размерность равна 3: **(w, h, num_channels)**, где **w** - ширина картинки в пикселях, **h** - высота картинки в пикселях, **num_channels** - количество каналов *(R, G, B, alpha)*.
#
# Вам нужно "развернуть" картинку в одномерный массив размера w \* h \* num_channels, написав **одну строку кода**.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Загрузим картинку. Если эта ячейка не сработает, смотрите дальше:

# %%
path_to_image = './image.jpg'
image_array = plt.imread(path_to_image)

# %% [markdown]
# Если Вы работаете в google colab или по каким-то еще причинам картинка с диска не загрузилась, можно попробовать загрузить через ссылку в интернете:

# %%
from PIL import Image
import requests
from io import BytesIO

path_to_image = 'https://github.com/hocop/sberbank_madmo/raw/master/day_1/homework/image.jpg'
# например: https://github.com/hocop/sberbank_madmo/raw/master/day_1/homework/image.jpg

response = requests.get(path_to_image)
img = Image.open(BytesIO(response.content))

image_array = np.array(img)

# %% [markdown]
# В любом случае, у Вас должен появиться объект `image_array`.
# Распечатаем его на экране:

# %%
plt.imshow(image_array);

# %%
image_array
# Out:
# array([[[202, 142, 106],
#         [202, 142, 106],
#         [202, 142, 106],
#         ...,
#         [251, 192, 176],
#         [251, 192, 176],
#         [251, 192, 176]],
#
#        [[202, 142, 106],
#         [202, 142, 106],
#         [202, 142, 106],
#         ...,
#         [251, 192, 176],
#         [251, 192, 176],
#         [251, 192, 176]],
#
#        [[202, 142, 106],
#         [202, 142, 106],
#         [202, 142, 106],
#         ...,
#         [251, 192, 176],
#         [251, 192, 176],
#         [251, 192, 176]],
#
#        ...,
#
#        [[154, 145, 138],
#         [156, 145, 139],
#         [158, 147, 141],
#         ...,
#         [178, 115,  64],
#         [176, 114,  65],
#         [174, 112,  63]],
#
#        [[161, 148, 142],
#         [162, 149, 141],
#         [164, 149, 142],
#         ...,
#         [178, 115,  64],
#         [176, 114,  63],
#         [173, 111,  60]],
#
#        [[166, 153, 145],
#         [168, 153, 146],
#         [168, 154, 145],
# ...

# %%
# Ваш код здесь
changed_array = image_array.ravel()

# %%
# Здесь выведите размерность нового массива
print(changed_array)
print(changed_array.ndim)
print(changed_array.shape)
# Out:
# [202 142 106 ... 173 111  60]
# 1
# (53747712,)

# %% [markdown]
# ## Задача 6*
# Дан текст в виде строки. Напишите функцию, которая возвращает словарь, где ключами являются уникальные слова из этого текста, а значениями - число раз, которое данное слово встретилось в тексте. Считать, что слова разделяются пробелами.

# %%
def count_tokens(text):
  
   words = text.split()
   d = {}
   
   for word in words:
     try:
         d[word] += 1
     except:
         d[word] = 1 

   return d

# %%
count_tokens("один два три пять четыре пять")
# Out:
# {'два': 1, 'один': 1, 'пять': 2, 'три': 1, 'четыре': 1}

# %% [markdown]
# # Очень бонусная часть
# за решение этих задач количество бонусных быллов будет начисляться непропорционально потраченному времени.

# %% [markdown]
# __Задача 7*:__ Описать класс комплексный чисел, поддерживающий представление в полярном виде. Произвести перегрузку магических методов для основных арифметических операций (+, -, *, /).

# %%
import math

class ComplexNumber(object):
    def __init__(self, radius, phase):
        self.radius = radius
        self.phase = phase % (2 * math.pi)
        
    def __add__(self, other):
        pass
    
    def __sub__(self, other):
        pass
    
    def __mul__(self, other):
        pass
    
    def __truediv__(self, other):
        pass

# %% [markdown]
# __Задача 8*:__ Составить описание класса для объектов-векторов, задаваемых координатами концов в N-мерном пространстве. Основой является список значений координат вектора. Обеспечить операции сложения и вычитания векторов с получением нового вектора (суммы или разности), вычисления скалярного произведения двух векторов, длины вектора, косинуса угла между векторами. Все операции, которые можно перегрузить с помощью магических методов, должны быть реализованы именно через них.

# %%
class Vector(object):
    def __init__(self, vector_dim_values):
        pass
        
    def __add__(self, other):
        pass
        
    def __sub__(self, other):
        pass
        
    def __mul__(self, other):
        pass
    
    def __len__(self):
        pass
    
    def cosine(self, other):
        pass

# %% [markdown]
# __Задача 9*:__ Опишите класс для хранения двумерных числовых матриц на основе списков. Реализуйте поэлементные математические операции (с помощью магических методов), операцию умножения матрицы (как метод `mat_prod` класса), транспонирование, поиска следа матрицы, а также поиск значения её определителя, если он существует, в противном случае соответствующий метод должен выводить сообщение об ошибке.
#
# Матрицу должно быть возможным создать из списка (в этом случае у неё будет одна строка), списка списков, или же передав явно три числа: число строк, число столбцов и значение по-умолчанию (которое можно не задавать, в этом случае оно принимается равным нулю). Все операции должны проверять корректность входных данных и выдавать информативное сообщение в случае ошибки.
#
# Матрица должна поддерживать метод сохранения на диск в текстовом файле и метод обратной загрузки с диска.
#
# В реализации запрещается пользоваться циклами, а также любыми функциями, не входящими в стандартную библиотеку языка (то есть требующими использования `import`).

# %%
class Matrix(object):
    def __init__(self, relative_value, width=None, default_value=0):
        pass
        
        
    def __add__(self, other):
        pass
        
    def __sub__(self, other):
        pass
    
    
    def __mul__(self, other):
        pass
    
    
    def __truediv__(self, other):
        pass
            
     
    def mat_prod(self, other):
        pass
        
        
    def transpose(self, inplace=False):
        pass
        
        
    def trace(self):
        pass
        
        
    def determinant(self):
        pass
        
    
    def save(self, path='Matrix.txt'):
        with open('Matrix.txt', 'w') as f:
            f.write(str(self.values))
        
    
    def load(self, path='Matrix.txt'):
        passS
